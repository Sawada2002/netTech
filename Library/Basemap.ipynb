# %%
# !pip install basemap basemap-data-hires
# Out:
# Requirement already satisfied: basemap in /Users/sawadahayato/.pyenv/versions/3.12.2/lib/python3.12/site-packages (1.4.1)
# Requirement already satisfied: basemap-data-hires in /Users/sawadahayato/.pyenv/versions/3.12.2/lib/python3.12/site-packages (1.3.2)
# Requirement already satisfied: basemap-data<1.4,>=1.3.2 in /Users/sawadahayato/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from basemap) (1.3.2)
# Requirement already satisfied: pyshp<2.4,>=1.2 in /Users/sawadahayato/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from basemap) (2.3.1)
# Requirement already satisfied: matplotlib<3.9,>=1.5 in /Users/sawadahayato/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from basemap) (3.8.4)
# Requirement already satisfied: pyproj<3.7.0,>=1.9.3 in /Users/sawadahayato/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from basemap) (3.6.1)
# Requirement already satisfied: packaging<24.0,>=16.0 in /Users/sawadahayato/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from basemap) (23.2)
# Requirement already satisfied: numpy<1.27,>=1.21 in /Users/sawadahayato/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from basemap) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/sawadahayato/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from matplotlib<3.9,>=1.5->basemap) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/sawadahayato/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from matplotlib<3.9,>=1.5->basemap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sawadahayato/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from matplotlib<3.9,>=1.5->basemap) (4.52.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/sawadahayato/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from matplotlib<3.9,>=1.5->basemap) (1.4.5)
# Requirement already satisfied: pillow>=8 in /Users/sawadahayato/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from matplotlib<3.9,>=1.5->basemap) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/sawadahayato/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from matplotlib<3.9,>=1.5->basemap) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sawadahayato/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from matplotlib<3.9,>=1.5->basemap) (2.9.0.post0)
# Requirement already satisfied: certifi in /Users/sawadahayato/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from pyproj<3.7.0,>=1.9.3->basemap) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /Users/sawadahayato/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib<3.9,>=1.5->basemap) (1.16.0)

# %% [markdown]
# ## 1. 必要なライブラリのインポート
# それぞれの使い方は以下のリンクを参照してみる
# 1. Basemapについて: https://yyousuke.github.io/matplotlib/basemap.html
# 2. Pyplotを使ったチュートリアル: https://matplotlib.org/2.0.2/users/pyplot_tutorial.html

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. 世界地図を描画してみる

# %%
# 図の作成
fig, ax = plt.subplots(figsize=(10, 7))

# Basemapの設定
m = Basemap(projection='mill', llcrnrlat=-60, urcrnrlat=90,
            llcrnrlon=-180, urcrnrlon=180, resolution='c', ax=ax)

# 海岸線、国境、経度線、緯度線の描画
m.drawcoastlines()
m.drawcountries()
m.drawparallels(range(-90, 91, 30), labels=[1,0,0,0])
m.drawmeridians(range(-180, 181, 60), labels=[0,0,0,1])

# 地図の表示
plt.title('World Map')
plt.show()

# %% [markdown]
# ## 3.都市の位置をプロットするプログラムの場合

# %%
# 図の作成
fig, ax = plt.subplots(figsize=(10, 7))

# Basemapの設定
m = Basemap(projection='mill', llcrnrlat=-60, urcrnrlat=90,
            llcrnrlon=-180, urcrnrlon=180, resolution='c', ax=ax)

# 海岸線，国境，経度線，緯度線を描画する
m.drawcoastlines() #海岸線
m.drawcountries() #国境
m.drawparallels(range(-90, 91, 30), labels=[1,0,0,0]) #軽度線
m.drawmeridians(range(-180, 181, 60), labels=[0,0,0,1]) #緯度線

# 都市の位置のプロット(東京,ニューヨーク,ロンドン,シドニー)
# 緯度と経度を指定してあげる
cities = {
    'Tokyo': (35.6895, 139.6917),
    'New York': (40.7128, -74.0060),
    'London': (51.5074, -0.1278),
    'Sydney': (-33.8688, 151.2093)
}

#上記で指定した年を順にプロット
for city, (lat, lon) in cities.items():
    x, y = m(lon, lat)
    m.plot(x, y, 'ro')
    plt.text(x, y, city, fontsize=12) #文字サイズの指定

# 地図の表示
plt.title('World Map with Major Cities')
plt.show()
